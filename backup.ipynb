# %%
from anytree import Node, RenderTree, PreOrderIter
import json
from pymongo import MongoClient
import glob
import json
import math

# %%
# client = MongoClient('mongodb+srv://user:user@cluster0.ard5c.mongodb.net/test')
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client.get_database('tweets')

# %%
loops = 100
count = db['timeline'].count()
batch_size = count / loops
batch_size = math.ceil(batch_size)

for i in range(loops):
    skip = batch_size*i
    # !mongoexport --uri="mongodb://127.0.0.1:27017/tweets"  --collection=timeline --skip={skip} --limit={batch_size} --out=timeline${i}.json
# Out:
# C:\Users\Akila\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#
# 2021-06-11T15:45:13.323+0530	connected to: mongodb://127.0.0.1:27017/tweets
# 2021-06-11T15:45:14.324+0530	[........................]  tweets.timeline  0/7  (0.0%)
# 2021-06-11T15:45:15.327+0530	[........................]  tweets.timeline  0/7  (0.0%)
# 2021-06-11T15:45:16.110+0530	[########################]  tweets.timeline  7/7  (100.0%)
# 2021-06-11T15:45:16.110+0530	exported 7 records
# 2021-06-11T15:45:16.214+0530	connected to: mongodb://127.0.0.1:27017/tweets
# 2021-06-11T15:45:17.216+0530	[........................]  tweets.timeline  0/7  (0.0%)
# 2021-06-11T15:45:18.215+0530	[........................]  tweets.timeline  0/7  (0.0%)
# ...
